# %%
from datasets import load_dataset

data_files = {"train": "SQuAD_it-train.json", "test": "SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")

# %%
# Loading a remote dataset
from datasets import load_dataset

url = "https://github.com/crux82/squad-it/raw/master/"
data_files = {
    "train": url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz",
}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       4 url = "https://github.com/crux82/squad-it/raw/master/"
#       5 data_files = {
#       6     "train": url + "SQuAD_it-train.json.gz",
#       7     "test": url + "SQuAD_it-test.json.gz",
#       8 }
# ----> 9 squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/load.py:2109, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2104 verification_mode = VerificationMode(
#    2105     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2106 )
#    2108 # Create a dataset builder
# -> 2109 builder_instance = load_dataset_builder(
#    2110     path=path,
#    2111     name=name,
#    2112     data_dir=data_dir,
#    2113     data_files=data_files,
#    2114     cache_dir=cache_dir,
#    2115     features=features,
#    2116     download_config=download_config,
#    2117     download_mode=download_mode,
#    2118     revision=revision,
#    2119     token=token,
#    2120     storage_options=storage_options,
#    2121     **config_kwargs,
#    2122 )
#    2124 # Return iterable dataset in case of streaming
#    2125 if streaming:
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/load.py:1795, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, **config_kwargs)
#    1793     download_config = download_config.copy() if download_config else DownloadConfig()
#    1794     download_config.storage_options.update(storage_options)
# -> 1795 dataset_module = dataset_module_factory(
#    1796     path,
#    1797     revision=revision,
#    1798     download_config=download_config,
#    1799     download_mode=download_mode,
#    1800     data_dir=data_dir,
#    1801     data_files=data_files,
#    1802 )
#    1803 # Get dataset builder class from the processing script
#    1804 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/load.py:1410, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1387 # We have several ways to get a dataset builder:
#    1388 #
#    1389 # - if path is the name of a packaged dataset module
#    (...)
#    1401
#    1402 # Try packaged
#    1403 if path in _PACKAGED_DATASETS_MODULES:
#    1404     return PackagedDatasetModuleFactory(
#    1405         path,
#    1406         data_dir=data_dir,
#    1407         data_files=data_files,
#    1408         download_config=download_config,
#    1409         download_mode=download_mode,
# -> 1410     ).get_module()
#    1411 # Try locally
#    1412 elif path.endswith(filename):
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/load.py:947, in PackagedDatasetModuleFactory.get_module(self)
#     945 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     946 patterns = sanitize_patterns(self.data_files) if self.data_files is not None else get_data_patterns(base_path)
# --> 947 data_files = DataFilesDict.from_patterns(
#     948     patterns,
#     949     download_config=self.download_config,
#     950     base_path=base_path,
#     951 )
#     952 supports_metadata = self.name in _MODULE_SUPPORTS_METADATA
#     953 if self.data_files is None and supports_metadata and patterns != DEFAULT_PATTERNS_ALL:
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/data_files.py:671, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     668 out = cls()
#     669 for key, patterns_for_key in patterns.items():
#     670     out[key] = (
# --> 671         DataFilesList.from_patterns(
#     672             patterns_for_key,
#     673             base_path=base_path,
#     674             allowed_extensions=allowed_extensions,
#     675             download_config=download_config,
#     676         )
#     677         if not isinstance(patterns_for_key, DataFilesList)
#     678         else patterns_for_key
#     679     )
#     680 return out
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/data_files.py:577, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     574 for pattern in patterns:
#     575     try:
#     576         data_files.extend(
# --> 577             resolve_pattern(
#     578                 pattern,
#     579                 base_path=base_path,
#     580                 allowed_extensions=allowed_extensions,
#     581                 download_config=download_config,
#     582             )
#     583         )
#     584     except FileNotFoundError:
#     585         pass
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/datasets/data_files.py:339, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     335 protocol_prefix = fs.protocol + "://" if fs.protocol != "file" else ""
#     336 files_to_ignore = set(FILES_TO_IGNORE) - {xbasename(pattern)}
#     337 matched_paths = [
#     338     filepath if filepath.startswith(protocol_prefix) else protocol_prefix + filepath
# --> 339     for filepath, info in fs.glob(pattern, detail=True).items()
#     340     if info["type"] == "file"
#     341     and (xbasename(filepath) not in files_to_ignore)
#     342     and not _is_inside_unrequested_special_dir(
#     343         os.path.relpath(filepath, fs_base_path), os.path.relpath(fs_pattern, fs_base_path)
#     344     )
#     345     and not _is_unrequested_hidden_file_or_is_inside_unrequested_hidden_dir(
#     346         os.path.relpath(filepath, fs_base_path), os.path.relpath(fs_pattern, fs_base_path)
#     347     )
#     348 ]  # ignore .ipynb and __pycache__, but keep /../
#     349 if allowed_extensions is not None:
#     350     out = [
#     351         filepath
#     352         for filepath in matched_paths
#     353         if any("." + suffix in allowed_extensions for suffix in xbasename(filepath).split(".")[1:])
#     354     ]
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/fsspec/asyn.py:115, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def wrapper(*args, **kwargs):
#     114     self = obj or args[0]
# --> 115     return sync(self.loop, func, *args, **kwargs)
#
# File ~/anaconda3/envs/vault/lib/python3.10/site-packages/fsspec/asyn.py:88, in sync(loop, func, timeout, *args, **kwargs)
#      85 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      86 while True:
#      87     # this loops allows thread to get interrupted
# ---> 88     if event.wait(1):
#      89         break
#      90     if timeout is not None:
#
# File ~/anaconda3/envs/vault/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/vault/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
